# %%
import sys
print(sys.version)
sys.path.append('../')
import pathlib 
from NicolasSamson.script.acceleration_dataset_analyzer import *
# Out:
# 3.8.19 (default, Apr  6 2024, 17:58:10)
# [GCC 11.4.0]

# %%
path_2_dataset1 = '../data/ral2023_dataset/warthog_wheels/gravel_1/acceleration_dataset.pkl'
path_2_dataset = '../data/ral2023_dataset/warthog_wheels/ice/acceleration_dataset.pkl'

ice_dataset = data_loader(path_2_dataset,verbose=False)
ice_dataset.process_the_acceleration_dataframe()

gravel_dataset = data_loader(path_2_dataset1,verbose=False)
gravel_dataset.process_the_acceleration_dataframe()
# Out:
# (394, 1578)
# (197, 1578)
# (591, 40)
# (240, 1458)
# (120, 1458)
# (360, 40)
# /home/nicolassamson/workspaces/norlab_WMRD/venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/nicolassamson/workspaces/norlab_WMRD/venv/lib/python3.8/site-packages/numpy/core/_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   ret = um.true_divide(
